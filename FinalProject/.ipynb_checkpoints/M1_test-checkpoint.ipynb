# %% [markdown]
# It is now time to start using everything you have learned in the first half of this class. The project for this course is to develop your own original analysis case study, and you will be working through and updating this project for the remainder of the term. The work you are doing on the Titanic case study in parallel is a guide for your original project, but you will need to adapt the analysis for your data/project.

# %% [markdown]
# The first step is coming up with an idea – arguably one of the hardest steps! Identify an original business problem for your project. There are lots of ideas available online through Kaggle and other sources, but your idea should have a unique spin on it. The second step is locating your data. This can come from a variety of sources, e.g., Kaggle, your job, a website, API, etc. Feel free to reach out to your instructor if you are not sure if your idea and data are suitable.

# %% [markdown]
# Begin Milestone 1 with a 250-500-word narrative describing an original idea for an analysis/model building business problem. Then, do a graphical analysis creating a minimum of four graphs. Label your graphs appropriately and explain/analyze the information provided by each graph. Keep in mind that your analysis may look very different from the Titanic tutorial graphical analysis. Write a short overview/conclusion of the insights gained from your graphical analysis.

# %% [markdown]
# As a reminder – Teams is a great place to discuss your project with your peers. Feel free to solicit feedback/input (without creating a group project!) and collaborate on your projects with your peers.
# Each milestone will build on top of each other, so make sure you do not fall behind.
# Submit Milestone 1 as a PDF or Jupyter Notebook, along with any applicable code to the submission link.

# %% [markdown]
# ## 1) Begin Milestone 1 with a 250-500-word narrative describing an original idea for an analysis/model building business problem.

# %% [markdown]
# ## 2) Then, do a graphical analysis creating a minimum of four graphs.
# Label your graphs appropriately and explain/analyze the information provided by each graph. Keep in mind that your analysis may look very different from the Titanic tutorial graphical analysis.

# %% [markdown]
# ## 3) Write a short overview/conclusion of the insights gained from your graphical analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel('Compiled_Lawsonia.xlsx')

# %%
data.shape
# Out:
# (465, 39)

# %%
save = data.copy()

# %%
data.head()
# Out:
#       Batch  Vessel DPI       Date      Time  Temp_C  Agitation  DO_pct  \
# 0  369697PV  Flasks   3 2019-07-12       NaN     NaN        NaN     NaN
# 1  369697PV  5L BLU   M 2019-07-12  09:25:00    36.0       40.0    7.37
# 2  369697PV  5L BLU   0 2019-07-12  10:53:00    35.8       40.0   15.39
# 3  369697PV  5L BLU   1 2019-07-13       NaN     NaN        NaN     NaN
# 4  369697PV  5L BLU   2 2019-07-14       NaN     NaN        NaN     NaN
#
#    pH_online  pH_offline  ...  Micro_Comments  Intra_Code  Extra_Code  \
# 0        NaN         NaN  ...             NaN         NaN         NaN
# 1      7.035       6.783  ...             NaN         NaN         NaN
# 2      6.983       7.118  ...             NaN         NaN         NaN
# 3        NaN         NaN  ...             NaN         NaN         NaN
# 4        NaN         NaN  ...             NaN         NaN         NaN
#
#    ELISA_KZO  ELISA_LNK  Live_Titer VCD_OD  RNA  gDNA/1mL  Antifoam
# 0        NaN        NaN         NaN    NaN  NaN       NaN       NaN
# 1        NaN        NaN         NaN    NaN  NaN       NaN       NaN
# 2        NaN        NaN         NaN    NaN  NaN       NaN       NaN
# 3        NaN        NaN         NaN    NaN  NaN       NaN       NaN
# 4        NaN        NaN         NaN    NaN  NaN       NaN       NaN
#
# [5 rows x 39 columns]

# %%
round(data.describe(), 2)
# Out:
#        Temp_C  Agitation  DO_pct  pH_online  pH_offline  O₂_%sat  CO₂_%sat  \
# count  371.00     371.00  371.00     372.00      294.00   271.00    275.00
# mean    35.99      49.62    6.86       7.05        7.06     1.24      0.08
# std      0.11      10.19    4.19       0.04        0.10     8.53      0.12
# min     34.78      40.00    0.16       6.61        6.66     0.03      0.01
# 25%     36.00      42.00    5.72       7.05        7.01     0.38      0.06
# 50%     36.00      48.90    6.00       7.05        7.05     0.48      0.08
# 75%     36.00      49.20    6.48       7.06        7.10     0.62      0.09
# max     36.40      67.30   41.74       7.14        7.52   100.00      1.90
#
#        L_Glut    Gluc    Lact  ...  Intra_Ct  Intra_Code  Extra_Code  \
# count  214.00  275.00  241.00  ...     76.00      196.00      196.00
# mean     1.03    3.94    0.25  ...     15.89        2.72        3.89
# std      1.05    0.68    0.28  ...     23.29        1.07        1.18
# min      0.00    1.08    0.00  ...      0.00        1.00        1.00
# 25%      0.09    3.69    0.09  ...      2.75        2.00        3.00
# 50%      0.76    4.14    0.18  ...      7.50        3.00        4.00
# 75%      1.68    4.40    0.30  ...     20.00        3.00        5.00
# max      6.96    4.90    1.76  ...    127.00        5.00        5.00
#
#        ELISA_KZO  ELISA_LNK  Live_Titer  VCD_OD        RNA      gDNA/1mL  \
# count      82.00      21.00        5.00   22.00      47.00  5.600000e+01
# mean     9263.34    6926.57        4.53    1.11   15827.86  1.960579e+08
# std      3295.63    2853.12        0.71    1.02   22378.75  1.507412e+08
# min      1630.00    3156.00        3.50   -0.40     170.00  2.545546e+06
# 25%      6617.25    4889.00        4.50    0.15    1478.96  7.661384e+07
# 50%      9670.25    5549.00        4.50    1.25    7378.63  1.359994e+08
# 75%     11124.50    9758.00        4.65    2.09   23748.48  2.879057e+08
# max     17020.00   11965.00        5.50    2.58  103762.66  6.374318e+08
#
#        Antifoam
# count       7.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
#
# [8 rows x 30 columns]

# %%
data.describe(include=['O'])
# Out:
#            Batch     Vessel  DPI      Time Nuc_NonVi Micro_Intra  \
# count        465        465  464       373       269         247
# unique        12          5   17       170        81           5
# top     484263PV  1000L SUB    3  08:48:00       <5k    Some, 2+
# freq          46        141   51         8       111          97
#
#            Micro_Extra Micro_Comments
# count              247            248
# unique               6             23
# top     Very Heavy, 4+           None
# freq               105            225

# %%
data.columns
# Out:
# Index(['Batch', 'Vessel', 'DPI', 'Date', 'Time', 'Temp_C', 'Agitation',
#        'DO_pct', 'pH_online', 'pH_offline', 'O₂_%sat', 'CO₂_%sat', 'L_Glut',
#        'Gluc', 'Lact', 'Ammon', 'Nuc_NonVi', 'Nuc_TotCt', 'Nuc_LiveCt',
#        'Nuc_Viab', 'MPbio_Blank', 'MPbio_Area', 'MPbio_TotCt', 'MPtvo_Blank',
#        'MPtvo_Area', 'MPtvo_TotCt', 'Intra_Ct', 'Micro_Intra', 'Micro_Extra',
#        'Micro_Comments', 'Intra_Code', 'Extra_Code', 'ELISA_KZO', 'ELISA_LNK',
#        'Live_Titer', 'VCD_OD', 'RNA', 'gDNA/1mL', 'Antifoam'],
#       dtype='object')

# %%
data.iloc[0]
# Out:
# Batch                        369697PV
# Vessel                         Flasks
# DPI                                 3
# Date              2019-07-12 00:00:00
# Time                              NaN
# Temp_C                            NaN
# Agitation                         NaN
# DO_pct                            NaN
# pH_online                         NaN
# pH_offline                        NaN
# O₂_%sat                           NaN
# CO₂_%sat                          NaN
# L_Glut                            NaN
# Gluc                              NaN
# Lact                              NaN
# Ammon                             NaN
# Nuc_NonVi                         <5k
# Nuc_TotCt                      648000
# Nuc_LiveCt                     643000
# Nuc_Viab                        0.992
# MPbio_Blank                      3596
# MPbio_Area                      55686
# MPbio_TotCt                   1.3e+07
# MPtvo_Blank                        21
# MPtvo_Area                      10645
# MPtvo_TotCt                  2.66e+06
# Intra_Ct                          NaN
# Micro_Intra                       NaN
# Micro_Extra                       NaN
# Micro_Comments                    NaN
# Intra_Code                        NaN
# Extra_Code                        NaN
# ELISA_KZO                         NaN
# ELISA_LNK                         NaN
# Live_Titer                        NaN
# VCD_OD                            NaN
# RNA                               NaN
# gDNA/1mL                          NaN
# Antifoam                          NaN
# Name: 0, dtype: object

# %%
data = data[data.DPI!='M']

# %%
data.Nuc_NonVi = data.Nuc_NonVi.replace('<5k', 5000/2)

# %%
data.Micro_Intra.unique()
# Out:
# array([nan, 'Light, 1+', 'Some, 2+', 'Heavy, 3+', 'Very Light, <1+',
#        'Very Heavy, 4+'], dtype=object)

# %%
dict = {'Very Light, <1+': 1, 'Light, 1+': 2, 'Some, 2+': 3, 'Heavy, 3+': 4, 'Very Heavy, 4+': 5}

# %%
data['Intra_Code'] = data['Micro_Intra'].map(dict)

# %%
data['Extra_Code'] = data['Micro_Extra'].map(dict)

# %% [markdown]
# Remove VCD_OD data for 471341PV

# %%
import numpy as np

# %%
data.loc[(data.Batch == '471341PV'), 'VCD_OD'] = np.nan

# %%
keepCols = ['Batch', 'Vessel', 'DPI', 
       'DO_pct', 'pH_online', 'pH_offline', 'O₂_%sat', 'CO₂_%sat', 'L_Glut',
       'Gluc', 'Lact', 'Ammon', 'Nuc_NonVi', 'Nuc_TotCt', 'Nuc_LiveCt',
       'Nuc_Viab', 'MPbio_TotCt',
       'MPtvo_TotCt', 'Intra_Ct', 'Micro_Intra', 'Micro_Extra',
       'Intra_Code', 'Extra_Code', 'ELISA_KZO',
       'Live_Titer', 'VCD_OD', 'RNA', 'gDNA/1mL', 'Antifoam']

# %%
newDF = data[keepCols]

# %%
newDF.head()
# Out:
#       Batch  Vessel DPI  DO_pct  pH_online  pH_offline  O₂_%sat  CO₂_%sat  \
# 0  369697PV  Flasks   3     NaN        NaN         NaN      NaN       NaN
# 2  369697PV  5L BLU   0   15.39      6.983       7.118    0.586     0.084
# 3  369697PV  5L BLU   1     NaN        NaN         NaN      NaN       NaN
# 4  369697PV  5L BLU   2     NaN        NaN         NaN      NaN       NaN
# 5  369697PV  5L BLU   3     NaN        NaN         NaN      NaN       NaN
#
#    L_Glut  Gluc  ...  Micro_Intra  Micro_Extra  Intra_Code  Extra_Code  \
# 0     NaN   NaN  ...          NaN          NaN         NaN         NaN
# 2     NaN   NaN  ...          NaN          NaN         NaN         NaN
# 3     NaN   NaN  ...          NaN          NaN         NaN         NaN
# 4     NaN   NaN  ...          NaN          NaN         NaN         NaN
# 5     NaN   NaN  ...          NaN          NaN         NaN         NaN
#
#    ELISA_KZO  Live_Titer  VCD_OD  RNA  gDNA/1mL Antifoam
# 0        NaN         NaN     NaN  NaN       NaN      NaN
# 2        NaN         NaN     NaN  NaN       NaN      NaN
# 3        NaN         NaN     NaN  NaN       NaN      NaN
# 4        NaN         NaN     NaN  NaN       NaN      NaN
# 5        NaN         NaN     NaN  NaN       NaN      NaN
#
# [5 rows x 29 columns]

# %%
newDF.iloc[:,3:]
# Out:
#      DO_pct  pH_online  pH_offline  O₂_%sat  CO₂_%sat  L_Glut  Gluc  Lact  \
# 0       NaN        NaN         NaN      NaN       NaN     NaN   NaN   NaN
# 2     15.39      6.983       7.118    0.586     0.084     NaN   NaN   NaN
# 3       NaN        NaN         NaN      NaN       NaN     NaN   NaN   NaN
# 4       NaN        NaN         NaN      NaN       NaN     NaN   NaN   NaN
# 5       NaN        NaN         NaN      NaN       NaN     NaN   NaN   NaN
# ..      ...        ...         ...      ...       ...     ...   ...   ...
# 460    5.44      7.050       6.951    0.390     0.069     0.0  2.91  0.24
# 461    6.07      7.050       7.103    0.480     0.044     0.0  2.67  0.30
# 462    6.14      7.050       7.072    0.384     0.047     0.0  2.54  0.25
# 463    5.73      7.050       7.024    0.386     0.055     0.0  2.44  0.19
# 464    3.49      7.060       7.078    0.404     0.044     0.0  2.40  0.10
#
#      Ammon  Nuc_NonVi  ...  Micro_Intra     Micro_Extra  Intra_Code  \
# 0      NaN     2500.0  ...          NaN             NaN         NaN
# 2     0.57     2500.0  ...          NaN             NaN         NaN
# 3      NaN        NaN  ...          NaN             NaN         NaN
# 4      NaN        NaN  ...          NaN             NaN         NaN
# 5      NaN        NaN  ...          NaN             NaN         NaN
# ..     ...        ...  ...          ...             ...         ...
# 460   5.90    90000.0  ...     Some, 2+  Very Heavy, 4+         3.0
# 461   5.91    69000.0  ...     Some, 2+  Very Heavy, 4+         3.0
# 462   5.93   124000.0  ...     Some, 2+  Very Heavy, 4+         3.0
# 463   5.75   192000.0  ...     Some, 2+  Very Heavy, 4+         3.0
# 464    NaN   195000.0  ...     Some, 2+  Very Heavy, 4+         3.0
#
#      Extra_Code  ELISA_KZO  Live_Titer VCD_OD RNA  gDNA/1mL  Antifoam
# 0           NaN        NaN         NaN    NaN NaN       NaN       NaN
# 2           NaN        NaN         NaN    NaN NaN       NaN       NaN
# 3           NaN        NaN         NaN    NaN NaN       NaN       NaN
# 4           NaN        NaN         NaN    NaN NaN       NaN       NaN
# 5           NaN        NaN         NaN    NaN NaN       NaN       NaN
# ..          ...        ...         ...    ...  ..       ...       ...
# 460         5.0        NaN         NaN    NaN NaN       NaN       NaN
# 461         5.0        NaN         NaN    NaN NaN       NaN       NaN
# 462         5.0        NaN         NaN    NaN NaN       NaN       NaN
# 463         5.0        NaN         NaN    NaN NaN       NaN       NaN
# 464         5.0        NaN         NaN    NaN NaN       NaN       NaN
#
# [423 rows x 26 columns]

# %%
newDF.iloc[2]
# Out:
# Batch          369697PV
# Vessel           5L BLU
# DPI                   1
# DO_pct              NaN
# pH_online           NaN
# pH_offline          NaN
# O₂_%sat             NaN
# CO₂_%sat            NaN
# L_Glut              NaN
# Gluc                NaN
# Lact                NaN
# Ammon               NaN
# Nuc_NonVi           NaN
# Nuc_TotCt           NaN
# Nuc_LiveCt          NaN
# Nuc_Viab            NaN
# MPbio_TotCt         NaN
# MPtvo_TotCt         NaN
# Intra_Ct            NaN
# Micro_Intra         NaN
# Micro_Extra         NaN
# Intra_Code          NaN
# Extra_Code          NaN
# ELISA_KZO           NaN
# Live_Titer          NaN
# VCD_OD              NaN
# RNA                 NaN
# gDNA/1mL            NaN
# Antifoam            NaN
# Name: 3, dtype: object

# %%
testDF = newDF.copy()

# %%
testDF.shape
# Out:
# (423, 29)

# %%
# testDF.dropna(thresh=20)

# %%
# testDF.dropna(thresh=1)

# %% [markdown]
# #### Remove rows without data

# %%
colList = testDF.columns[3:]

# %%
testDF.dropna(axis=0, subset=colList, how="all", inplace=True)

# %%
testDF.loc[0]
# Out:
# Batch          369697PV
# Vessel           Flasks
# DPI                   3
# DO_pct              NaN
# pH_online           NaN
# pH_offline          NaN
# O₂_%sat             NaN
# CO₂_%sat            NaN
# L_Glut              NaN
# Gluc                NaN
# Lact                NaN
# Ammon               NaN
# Nuc_NonVi          2500
# Nuc_TotCt        648000
# Nuc_LiveCt       643000
# Nuc_Viab          0.992
# MPbio_TotCt     1.3e+07
# MPtvo_TotCt    2.66e+06
# Intra_Ct            NaN
# Micro_Intra         NaN
# Micro_Extra         NaN
# Intra_Code          NaN
# Extra_Code          NaN
# ELISA_KZO           NaN
# Live_Titer          NaN
# VCD_OD              NaN
# RNA                 NaN
# gDNA/1mL            NaN
# Antifoam            NaN
# Name: 0, dtype: object

# %%
testDF.shape
# Out:
# (352, 29)

# %%
y = data.MPbio_TotCt

# %%
x = data.DPI

# %%
import numpy as np

# %%
plt.scatter(x, y)

# %%
# plt.scatter(x, y)
# m, b = np.polyfit(x, y, 1)
# plt.plot(x, m*x+b)

# %%
import seaborn as sns

# %%
sns.stripplot(x="DPI", y="MPbio_TotCt", data=data, jitter=0.5)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
sns.scatterplot(x="DPI", y="MPbio_TotCt", data=data, x_jitter=0.5)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
import statsmodels.api as sm

# %%
df = data.copy()

# %%
# df = df.astype('float')

# %%
# for i in df.columns:
#     if not pd.isnull(df[i]).any():
#         for j in df.columns:
#             if j != i and not pd.isnull(df[j]).any():
#                 model = sm.OLS(df[j], df[i]).fit()
#                 if model.rsquared > 0.40:
#                     df.plot.scatter(x=i, y=j)
#                     sns.regplot(x=i, y=j, data=df)
#                     fig = plt.gcf()
# #                     fig.suptitle("")

# %%
df[pd.isnull(df.DPI)]#.any()
# Out:
#         Batch   Vessel  DPI Date Time  Temp_C  Agitation  DO_pct  pH_online  \
# 218  458161PV  50L BLU  NaN  NaT  NaN     NaN        NaN     NaN        NaN
#
#      pH_offline  ...  Micro_Comments  Intra_Code  Extra_Code  ELISA_KZO  \
# 218         NaN  ...             NaN         NaN         NaN        NaN
#
#      ELISA_LNK  Live_Titer  VCD_OD  RNA  gDNA/1mL  Antifoam
# 218        NaN         NaN     NaN  NaN       NaN       NaN
#
# [1 rows x 39 columns]

# %%
df.iloc[196:203]
# Out:
#         Batch    Vessel  DPI       Date      Time  Temp_C  Agitation  DO_pct  \
# 215  458161PV   50L BLU    6 2020-09-08  08:54:00   36.01       42.0    5.98
# 216  458161PV   50L BLU    7 2020-09-09  09:09:00   36.00       42.0    5.86
# 217  458161PV   50L BLU    8 2020-09-10  08:39:00   36.00       42.0    6.06
# 218  458161PV   50L BLU  NaN        NaT       NaN     NaN        NaN     NaN
# 220  458161PV  250L SUB    0 2020-09-10  09:31:00   35.91       67.0    3.96
# 221  458161PV  250L SUB    1 2020-09-11  14:07:00   36.01       66.9    4.63
# 222  458161PV  250L SUB    2 2020-09-12  10:02:00   35.98       66.9    6.19
#
#      pH_online  pH_offline  ...                Micro_Comments  Intra_Code  \
# 215       7.05       7.048  ...  More intra than previous day         3.0
# 216       7.05       7.043  ...                          None         3.0
# 217       7.05       7.000  ...                          None         3.0
# 218        NaN         NaN  ...                           NaN         NaN
# 220       7.06       7.011  ...                          None         2.0
# 221       7.06         NaN  ...                           NaN         NaN
# 222       7.06         NaN  ...                           NaN         NaN
#
#      Extra_Code  ELISA_KZO  ELISA_LNK  Live_Titer  VCD_OD  RNA  gDNA/1mL  \
# 215         4.0        NaN        NaN         NaN     NaN  NaN       NaN
# 216         5.0        NaN        NaN         NaN     NaN  NaN       NaN
# 217         5.0        NaN        NaN         NaN     NaN  NaN       NaN
# 218         NaN        NaN        NaN         NaN     NaN  NaN       NaN
# 220         2.0        NaN        NaN         NaN     NaN  NaN       NaN
# 221         NaN        NaN        NaN         NaN     NaN  NaN       NaN
# 222         NaN        NaN        NaN         NaN     NaN  NaN       NaN
#
#      Antifoam
# 215       NaN
# 216       NaN
# 217       NaN
# 218       NaN
# 220       NaN
# 221       NaN
# 222       NaN
#
# [7 rows x 39 columns]

# %%
len(df)
# Out:
# 423

# %%
df = df[df['DPI'].notnull()]

# %%
# df[df['MPbio_TotCt'].isnull()]

# %%
MPBdf = df[pd.notnull(df.MPbio_TotCt)]
# df['MPbio_TotCt'].isnull()

# %%
# data.plot.scatter(x, y)

# %%
sns.scatterplot(x="DPI", y="MPbio_TotCt", data=MPBdf)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
MPBdf['DPI'] = MPBdf['DPI'].astype(float)
# Out:
# <ipython-input-126-90e4d5f0d662>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MPBdf['DPI'] = MPBdf['DPI'].astype(float)

# %%
MPBdf.plot.scatter(x='DPI', y='MPbio_TotCt')
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
df.plot.scatter(x='DPI', y='MPbio_TotCt')
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
MPBdf.dtypes
# Out:
# Batch                     object
# Vessel                    object
# DPI                      float64
# Date              datetime64[ns]
# Time                      object
# Temp_C                   float64
# Agitation                float64
# DO_pct                   float64
# pH_online                float64
# pH_offline               float64
# O₂_%sat                  float64
# CO₂_%sat                 float64
# L_Glut                   float64
# Gluc                     float64
# Lact                     float64
# Ammon                    float64
# Nuc_NonVi                float64
# Nuc_TotCt                float64
# Nuc_LiveCt               float64
# Nuc_Viab                 float64
# MPbio_Blank              float64
# MPbio_Area               float64
# MPbio_TotCt              float64
# MPtvo_Blank              float64
# MPtvo_Area               float64
# MPtvo_TotCt              float64
# Intra_Ct                 float64
# Micro_Intra               object
# Micro_Extra               object
# Micro_Comments            object
# Intra_Code               float64
# Extra_Code               float64
# ELISA_KZO                float64
# ELISA_LNK                float64
# Live_Titer               float64
# VCD_OD                   float64
# RNA                      float64
# gDNA/1mL                 float64
# Antifoam                 float64
# dtype: object

# %%
sns.regplot(x="DPI", y="MPbio_TotCt", data=MPBdf)#, dropna=True)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
# df.dtypes

# %%
sns.lmplot(x="DPI", y="MPbio_TotCt", data=MPBdf, x_jitter=0.5) #, order=2, ci=None)

# %%
df['DPI'] = df['DPI'].astype(float)

# %%
sns.lmplot(x="DPI", y="MPbio_TotCt", data=df, x_jitter=0.5, order=1)# , ci=None)

# %%
sns.regplot(x="DPI", y="MPbio_TotCt", data=df, x_jitter=0.5)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
sns.stripplot(x="DPI", y="MPbio_TotCt", data=df, jitter=0.5)
# Out:
# <AxesSubplot:xlabel='DPI', ylabel='MPbio_TotCt'>

# %%
y = data.MPtvo_TotCt
plt.scatter(x, y)

# %%
data[data.MPtvo_TotCt>8e9]
# Out:
#         Batch   Vessel DPI       Date      Time  Temp_C  Agitation  DO_pct  \
# 179  457597PV  50L BLU   3 2020-08-17  09:25:00    36.0       42.0    5.59
#
#      pH_online  pH_offline  ...  Micro_Comments  Intra_Code  Extra_Code  \
# 179       7.05       6.983  ...            None         2.0         3.0
#
#      ELISA_KZO  ELISA_LNK  Live_Titer VCD_OD  RNA  gDNA/1mL  Antifoam
# 179        NaN        NaN         NaN    NaN  NaN       NaN       NaN
#
# [1 rows x 38 columns]

# %%
data[data.MPtvo_TotCt>8e9].iloc[0]
# Out:
# Batch                        457597PV
# Vessel                        50L BLU
# DPI                                 3
# Date              2020-08-17 00:00:00
# Time                         09:25:00
# Temp_C                             36
# Agitation                          42
# DO_pct                           5.59
# pH_online                        7.05
# pH_offline                      6.983
# O₂_%sat                         0.491
# CO₂_%sat                        0.092
# L_Glut                           0.58
# Gluc                             4.21
# Lact                             0.07
# Ammon                             NaN
# Nuc_NonVi                         <5k
# Nuc_TotCt                       57000
# Nuc_LiveCt                      52000
# Nuc_Viab                     0.912281
# MPbio_Blank                       413
# MPbio_Area                     149110
# MPbio_TotCt                  3.72e+07
# MPtvo_Blank                        11
# MPtvo_Area                      39381
# MPtvo_TotCt                 9.384e+09
# Micro_Intra                 Light, 1+
# Micro_Extra                  Some, 2+
# Micro_Comments                   None
# Intra_Code                          2
# Extra_Code                          3
# ELISA_KZO                         NaN
# ELISA_LNK                         NaN
# Live_Titer                        NaN
# VCD_OD                            NaN
# RNA                               NaN
# gDNA/1mL                          NaN
# Antifoam                          NaN
# Name: 179, dtype: object

# %%
data[data.MPtvo_TotCt>8e9].iloc[0,25]
# Out:
# 9384000000.0

# %% [markdown]
# ##### 457597PV, 50L BLU, D3, TVO should be 9.84E+06, not 9.384E+09

# %%
# data[data.MPtvo_TotCt>8e9].iloc[0,25] = 9.84e6

# %%
data.loc[179, 'MPtvo_TotCt']
# Out:
# 9384000000.0

# %%
# data.loc[179, 'MPtvo_TotCt'] = 9.84e6

# %%
data.reindex()
# Out:
#         Batch     Vessel DPI       Date      Time  Temp_C  Agitation  DO_pct  \
# 0    369697PV     Flasks   3 2019-07-12       NaN     NaN        NaN     NaN
# 2    369697PV     5L BLU   0 2019-07-12  10:53:00    35.8       40.0   15.39
# 3    369697PV     5L BLU   1 2019-07-13       NaN     NaN        NaN     NaN
# 4    369697PV     5L BLU   2 2019-07-14       NaN     NaN        NaN     NaN
# 5    369697PV     5L BLU   3 2019-07-15       NaN     NaN        NaN     NaN
# ..        ...        ...  ..        ...       ...     ...        ...     ...
# 414  484262PV  1000L SUB   8 2021-03-25  08:45:00    36.0       49.0    4.64
# 415  484262PV  1000L SUB   9 2021-03-26  08:42:00    36.0       49.1    4.84
# 416  484262PV  1000L SUB  10 2021-03-27  06:51:00    36.0       49.1    5.42
# 417  484262PV  1000L SUB  11 2021-03-28  08:22:00    36.0       49.0    5.75
# 418  484262PV  1000L SUB  12 2021-03-29  07:47:00    36.0       48.9    6.01
#
#      pH_online  pH_offline  ...  Micro_Comments  Intra_Code  Extra_Code  \
# 0          NaN         NaN  ...             NaN         NaN         NaN
# 2        6.983       7.118  ...             NaN         NaN         NaN
# 3          NaN         NaN  ...             NaN         NaN         NaN
# 4          NaN         NaN  ...             NaN         NaN         NaN
# 5          NaN         NaN  ...             NaN         NaN         NaN
# ..         ...         ...  ...             ...         ...         ...
# 414      6.960       6.901  ...            None         NaN         NaN
# 415      6.950       6.947  ...            None         NaN         NaN
# 416      6.950       6.933  ...  Intra maybe 1+         NaN         NaN
# 417      6.960       6.903  ...            None         NaN         NaN
# 418      6.990       6.991  ...            None         NaN         NaN
#
#      ELISA_KZO  ELISA_LNK  Live_Titer VCD_OD  RNA     gDNA/1mL  Antifoam
# 0          NaN        NaN         NaN    NaN  NaN          NaN       NaN
# 2          NaN        NaN         NaN    NaN  NaN          NaN       NaN
# 3          NaN        NaN         NaN    NaN  NaN          NaN       NaN
# 4          NaN        NaN         NaN    NaN  NaN          NaN       NaN
# 5          NaN        NaN         NaN    NaN  NaN          NaN       NaN
# ..         ...        ...         ...    ...  ...          ...       ...
# 414    10201.5        NaN         NaN    NaN  NaN  413133025.0       NaN
# 415    10748.5        NaN         NaN    NaN  NaN  427727650.0       NaN
# 416    10903.0        NaN         NaN    NaN  NaN  333454400.0       NaN
# 417    11367.0        NaN         NaN    NaN  NaN  326340975.0       NaN
# 418    11336.0        NaN         NaN    NaN  NaN  311622775.0       NaN
#
# [381 rows x 38 columns]

# %%
data[data.MPtvo_TotCt>8e9].iloc[0]
# Out:
# Batch                        457597PV
# Vessel                        50L BLU
# DPI                                 3
# Date              2020-08-17 00:00:00
# Time                         09:25:00
# Temp_C                             36
# Agitation                          42
# DO_pct                           5.59
# pH_online                        7.05
# pH_offline                      6.983
# O₂_%sat                         0.491
# CO₂_%sat                        0.092
# L_Glut                           0.58
# Gluc                             4.21
# Lact                             0.07
# Ammon                             NaN
# Nuc_NonVi                         <5k
# Nuc_TotCt                       57000
# Nuc_LiveCt                      52000
# Nuc_Viab                     0.912281
# MPbio_Blank                       413
# MPbio_Area                     149110
# MPbio_TotCt                  3.72e+07
# MPtvo_Blank                        11
# MPtvo_Area                      39381
# MPtvo_TotCt                 9.384e+09
# Micro_Intra                 Light, 1+
# Micro_Extra                  Some, 2+
# Micro_Comments                   None
# Intra_Code                          2
# Extra_Code                          3
# ELISA_KZO                         NaN
# ELISA_LNK                         NaN
# Live_Titer                        NaN
# VCD_OD                            NaN
# RNA                               NaN
# gDNA/1mL                          NaN
# Antifoam                          NaN
# Name: 179, dtype: object

# %%
data.loc[179, 'MPtvo_TotCt']
# Out:
# 9384000000.0

# %%
data.loc[179, 'MPtvo_TotCt'] = 9.84e6

# %%
data.loc[179, 'MPtvo_TotCt']
# Out:
# 9840000.0

# %%
y = data.MPtvo_TotCt
plt.scatter(x, y)

# %%
# sns.pairplot(data)

# %%
sns.pairplot(testDF)

# %%
testDF.columns
# Out:
# Index(['Batch', 'Vessel', 'DPI', 'DO_pct', 'pH_online', 'pH_offline',
#        'O₂_%sat', 'CO₂_%sat', 'L_Glut', 'Gluc', 'Lact', 'Ammon', 'Nuc_NonVi',
#        'Nuc_TotCt', 'Nuc_LiveCt', 'Nuc_Viab', 'MPbio_TotCt', 'MPtvo_TotCt',
#        'Micro_Intra', 'Micro_Extra', 'Intra_Code', 'Extra_Code', 'ELISA_KZO',
#        'Live_Titer', 'VCD_OD', 'RNA', 'gDNA/1mL', 'Antifoam'],
#       dtype='object')

# %%
corrDF = testDF.corr()
corrDF
# Out:
#                DO_pct  pH_online  pH_offline   O₂_%sat  CO₂_%sat    L_Glut  \
# DO_pct       1.000000   0.112154    0.059068  0.013890  0.112434  0.326661
# pH_online    0.112154   1.000000    0.509260  0.055382  0.303445  0.098585
# pH_offline   0.059068   0.509260    1.000000  0.407878  0.335686  0.041476
# O₂_%sat      0.013890   0.055382    0.407878  1.000000  0.900813 -0.087391
# CO₂_%sat     0.112434   0.303445    0.335686  0.900813  1.000000 -0.059443
# L_Glut       0.326661   0.098585    0.041476 -0.087391 -0.059443  1.000000
# Gluc         0.200167   0.408836    0.236208  0.018034  0.103052  0.440882
# Lact        -0.144424  -0.575045   -0.221693  0.093555 -0.014546 -0.117958
# Ammon       -0.306162  -0.238171   -0.209248 -0.022819 -0.074947 -0.749957
# Nuc_NonVi   -0.157706  -0.052861   -0.044664 -0.036796 -0.052852 -0.510482
# Nuc_TotCt   -0.225415  -0.150762   -0.075996  0.070008  0.025455 -0.659159
# Nuc_LiveCt  -0.226430  -0.155906   -0.076229  0.078948  0.035013 -0.654684
# Nuc_Viab    -0.032046  -0.058990    0.028777  0.073830  0.072167  0.010963
# MPbio_TotCt -0.240163  -0.098610   -0.066789 -0.076831 -0.118755 -0.677981
# MPtvo_TotCt -0.175424  -0.278768   -0.245418 -0.069674 -0.140426 -0.517288
# Intra_Code  -0.145863  -0.061940   -0.117289 -0.152099 -0.139676 -0.431539
# Extra_Code  -0.380320  -0.140923   -0.159511 -0.196103 -0.205886 -0.669411
# ELISA_KZO    0.073006   0.114055    0.028297 -0.153240 -0.111561 -0.417699
# Live_Titer  -0.857695  -0.873483   -0.701654  0.060228 -0.722276       NaN
# VCD_OD      -0.644800  -0.769757   -0.753275 -0.407834 -0.633033 -1.000000
# RNA          0.013532   0.085701    0.030460  0.022853  0.139728 -0.115538
# gDNA/1mL    -0.061950  -0.495516   -0.610189 -0.021842  0.072755 -0.807419
# Antifoam          NaN        NaN         NaN       NaN       NaN       NaN
#
#                  Gluc      Lact     Ammon  Nuc_NonVi  ...  MPbio_TotCt  \
# DO_pct       0.200167 -0.144424 -0.306162  -0.157706  ...    -0.240163
# pH_online    0.408836 -0.575045 -0.238171  -0.052861  ...    -0.098610
# pH_offline   0.236208 -0.221693 -0.209248  -0.044664  ...    -0.066789
# O₂_%sat      0.018034  0.093555 -0.022819  -0.036796  ...    -0.076831
# CO₂_%sat     0.103052 -0.014546 -0.074947  -0.052852  ...    -0.118755
# L_Glut       0.440882 -0.117958 -0.749957  -0.510482  ...    -0.677981
# Gluc         1.000000 -0.613893 -0.712752  -0.564455  ...    -0.663395
# Lact        -0.613893  1.000000  0.273822   0.084803  ...     0.201211
# Ammon       -0.712752  0.273822  1.000000   0.770028  ...     0.876714
# Nuc_NonVi   -0.564455  0.084803  0.770028   1.000000  ...     0.752583
# Nuc_TotCt   -0.745492  0.200340  0.881240   0.725808  ...     0.719711
# Nuc_LiveCt  -0.741055  0.206979  0.867775   0.680675  ...     0.696332
# Nuc_Viab     0.110572 -0.001131 -0.091701  -0.458360  ...    -0.294949
# MPbio_TotCt -0.663395  0.201211  0.876714   0.752583  ...     1.000000
# MPtvo_TotCt -0.610956  0.366473  0.687679   0.395251  ...     0.668530
# Intra_Code  -0.334185  0.013364  0.597925   0.478064  ...     0.520004
# Extra_Code  -0.577173  0.220911  0.844830   0.584423  ...     0.795113
# ELISA_KZO   -0.251983 -0.022650  0.474429   0.441810  ...     0.746065
# Live_Titer  -0.459863  0.536199  0.202649   0.335174  ...     0.682768
# VCD_OD      -0.745869  0.746643  0.918370   0.868025  ...     0.956162
# RNA          0.129989 -0.252464  0.181657   0.138365  ...    -0.075884
# gDNA/1mL    -0.654513  0.438365  0.921292   0.817603  ...     0.846170
# Antifoam          NaN       NaN       NaN        NaN  ...          NaN
#
#              MPtvo_TotCt  Intra_Code  Extra_Code  ELISA_KZO  Live_Titer  \
# DO_pct         -0.175424   -0.145863   -0.380320   0.073006   -0.857695
# pH_online      -0.278768   -0.061940   -0.140923   0.114055   -0.873483
# pH_offline     -0.245418   -0.117289   -0.159511   0.028297   -0.701654
# O₂_%sat        -0.069674   -0.152099   -0.196103  -0.153240    0.060228
# CO₂_%sat       -0.140426   -0.139676   -0.205886  -0.111561   -0.722276
# L_Glut         -0.517288   -0.431539   -0.669411  -0.417699         NaN
# Gluc           -0.610956   -0.334185   -0.577173  -0.251983   -0.459863
# Lact            0.366473    0.013364    0.220911  -0.022650    0.536199
# Ammon           0.687679    0.597925    0.844830   0.474429    0.202649
# Nuc_NonVi       0.395251    0.478064    0.584423   0.441810    0.335174
# Nuc_TotCt       0.509834    0.533444    0.673321   0.130641    0.398842
# Nuc_LiveCt      0.506475    0.524480    0.662704   0.081237    0.275217
# Nuc_Viab       -0.068700   -0.068605   -0.089043  -0.387428   -0.208168
# MPbio_TotCt     0.668530    0.520004    0.795113   0.746065    0.682768
# MPtvo_TotCt     1.000000    0.474532    0.642438   0.194619   -0.830734
# Intra_Code      0.474532    1.000000    0.689946  -0.039128   -0.433309
# Extra_Code      0.642438    0.689946    1.000000   0.433506         NaN
# ELISA_KZO       0.194619   -0.039128    0.433506   1.000000    0.620955
# Live_Titer     -0.830734   -0.433309         NaN   0.620955    1.000000
# VCD_OD          0.489553    0.253008    0.929353   0.822339    0.866064
# RNA            -0.146718    0.381751    0.095494  -0.195724         NaN
# gDNA/1mL        0.874696    0.748217    0.760366  -0.805817         NaN
# Antifoam             NaN         NaN         NaN        NaN         NaN
#
#                VCD_OD       RNA  gDNA/1mL  Antifoam
# DO_pct      -0.644800  0.013532 -0.061950       NaN
# pH_online   -0.769757  0.085701 -0.495516       NaN
# pH_offline  -0.753275  0.030460 -0.610189       NaN
# O₂_%sat     -0.407834  0.022853 -0.021842       NaN
# CO₂_%sat    -0.633033  0.139728  0.072755       NaN
# L_Glut      -1.000000 -0.115538 -0.807419       NaN
# Gluc        -0.745869  0.129989 -0.654513       NaN
# Lact         0.746643 -0.252464  0.438365       NaN
# Ammon        0.918370  0.181657  0.921292       NaN
# Nuc_NonVi    0.868025  0.138365  0.817603       NaN
# Nuc_TotCt    0.839233  0.404341  0.718465       NaN
# Nuc_LiveCt   0.799744  0.417410  0.686515       NaN
# Nuc_Viab    -0.587653  0.051129 -0.131469       NaN
# MPbio_TotCt  0.956162 -0.075884  0.846170       NaN
# MPtvo_TotCt  0.489553 -0.146718  0.874696       NaN
# Intra_Code   0.253008  0.381751  0.748217       NaN
# Extra_Code   0.929353  0.095494  0.760366       NaN
# ELISA_KZO    0.822339 -0.195724 -0.805817       NaN
# Live_Titer   0.866064       NaN       NaN       NaN
# VCD_OD       1.000000       NaN       NaN       NaN
# RNA               NaN  1.000000 -0.327823       NaN
# gDNA/1mL          NaN -0.327823  1.000000       NaN
# Antifoam          NaN       NaN       NaN       NaN
#
# [23 rows x 23 columns]

# %%
testDF.corrwith(testDF.MPbio_TotCt).sort_values(ascending=False)
# Out:
# MPbio_TotCt    1.000000
# VCD_OD         0.956162
# Ammon          0.876714
# gDNA/1mL       0.846170
# Extra_Code     0.795113
# Nuc_NonVi      0.752583
# ELISA_KZO      0.746065
# Nuc_TotCt      0.719711
# Nuc_LiveCt     0.696332
# Live_Titer     0.682768
# MPtvo_TotCt    0.668530
# Intra_Code     0.520004
# Lact           0.201211
# pH_offline    -0.066789
# RNA           -0.075884
# O₂_%sat       -0.076831
# pH_online     -0.098610
# CO₂_%sat      -0.118755
# DO_pct        -0.240163
# Nuc_Viab      -0.294949
# Gluc          -0.663395
# L_Glut        -0.677981
# Antifoam            NaN
# dtype: float64

# %%
testDF.corrwith(testDF.ELISA_KZO).sort_values(ascending=False)
# Out:
# ELISA_KZO      1.000000
# VCD_OD         0.822339
# MPbio_TotCt    0.746065
# Live_Titer     0.620955
# Ammon          0.474429
# Nuc_NonVi      0.441810
# Extra_Code     0.433506
# MPtvo_TotCt    0.194619
# Nuc_TotCt      0.130641
# pH_online      0.114055
# Nuc_LiveCt     0.081237
# DO_pct         0.073006
# pH_offline     0.028297
# Lact          -0.022650
# Intra_Code    -0.039128
# CO₂_%sat      -0.111561
# O₂_%sat       -0.153240
# RNA           -0.195724
# Gluc          -0.251983
# Nuc_Viab      -0.387428
# L_Glut        -0.417699
# gDNA/1mL      -0.805817
# Antifoam            NaN
# dtype: float64

# %%
testDF.corrwith(testDF.VCD_OD).sort_values(ascending=False)
# Out:
# VCD_OD         1.000000
# MPbio_TotCt    0.956162
# Extra_Code     0.929353
# Ammon          0.918370
# Nuc_NonVi      0.868025
# Live_Titer     0.866064
# Nuc_TotCt      0.839233
# ELISA_KZO      0.822339
# Nuc_LiveCt     0.799744
# Lact           0.746643
# MPtvo_TotCt    0.489553
# Intra_Code     0.253008
# O₂_%sat       -0.407834
# Nuc_Viab      -0.587653
# CO₂_%sat      -0.633033
# DO_pct        -0.644800
# Gluc          -0.745869
# pH_offline    -0.753275
# pH_online     -0.769757
# L_Glut        -1.000000
# RNA                 NaN
# gDNA/1mL            NaN
# Antifoam            NaN
# dtype: float64
