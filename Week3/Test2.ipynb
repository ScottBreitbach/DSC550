# %%
import pandas as pd
from sklearn import datasets
import numpy as np

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (10, 6)

# %%
cmap = plt.get_cmap('tab20c')
colors = cmap(np.arange(4)*4)

# %%
iris_data = pd.DataFrame(datasets.load_iris().data)
iris_data.columns = datasets.load_iris().feature_names
iris_data['target'] = datasets.load_iris().target

# %%
iris_data['target name'] = iris_data.target

# %%
name = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
testDF = iris_data.copy()

# %%
testDF.replace({'target name': name}, inplace=True)

# %%
testDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
import matplotlib.pyplot as plt

# %%
irisDF = pd.DataFrame(datasets.load_iris().data)
irisDF.columns = datasets.load_iris().feature_names
irisDF['target'] = datasets.load_iris().target
irisDF['flower name'] = datasets.load_iris().target
rename = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
irisDF.replace({'flower name': rename}, inplace=True)

# %%
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
datasets.load_iris().target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# names = ['setosa', 'versicolor', 'virginica']
plt.plot('sepal length (cm)', 'sepal width (cm)', 'o', data=irisDF)
plt.show()

# %%
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

# %%
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}
plt.scatter('sepal length (cm)', 'sepal width (cm)', 
            c=irisDF['flower name'].apply(lambda x: colors[x]), data=irisDF)
plt.show()

# %%
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}
plt.scatter('sepal length (cm)', 'sepal width (cm)', 
            c=irisDF['flower name'].map(colors), data=irisDF)
plt.show()

# %%
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}
plt.scatter('petal length (cm)', 'petal width (cm)',
            c=irisDF['flower name'].map(colors), data=irisDF)
plt.show()

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %%
colors = {'setosa': cmap([0])[0], 'versicolor': cmap([4])[0], 'virginica': cmap([8])[0]}

plt.scatter('sepal length (cm)', 'sepal width (cm)', marker="^", alpha=.75,
            c=irisDF['flower name'].map(colors), data=irisDF)
plt.scatter('petal length (cm)', 'petal width (cm)', alpha=.75,
            c=irisDF['flower name'].map(colors), data=irisDF)

plt.legend(['sepals', 'petals'])
legend_elements = [Line2D([0], [0], marker='^', color='w', markerfacecolor='gray', label='sepals', markersize=10),
                   Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', label='petals', markersize=10),
                   Patch(facecolor=cmap([0])[0], label='setosa'), 
                   Patch(facecolor=cmap([4])[0], label='versicolor'), 
                   Patch(facecolor=cmap([8])[0], label='virginica')]
plt.legend(handles=legend_elements, loc=2)

plt.xlabel('Length (cm)')
plt.ylabel('Width (cm)')
plt.rcParams['axes.titlesize'] = 20
plt.title('Measurements by Species and Type', )

plt.show()

# %%
# irisDF.plot.bar()

# %%
irisDF.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
irisDF.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'flower name'],
#       dtype='object')

# %%
objects = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# plt.bar(objects, 'flower name', data=irisDF)

# %%
irisDF['sepal length (cm)'].mean()
# Out:
# 5.843333333333335

# %%
# X = np.arange(4)
# plt.bar(X + 0.00, iris)

# %%
datasets.load_iris().target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()
# Out:
# flower name
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal length (cm), dtype: float64

# %%
irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()[0]
# Out:
# 5.005999999999999

# %%
irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()[1]
# Out:
# 5.936

# %% [markdown]
# ### Bar Chart
# https://pythonspot.com/matplotlib-bar-chart/

# %%
labels = ['sepal length', 'sepal width', 'petal length', 'petal width']
setosa_means = [irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()[0], 
                irisDF['sepal width (cm)'].groupby(irisDF['flower name']).mean()[0], 
                irisDF['petal length (cm)'].groupby(irisDF['flower name']).mean()[0], 
                irisDF['petal width (cm)'].groupby(irisDF['flower name']).mean()[0]]
versicolor_means = [irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()[1], 
                irisDF['sepal width (cm)'].groupby(irisDF['flower name']).mean()[1], 
                irisDF['petal length (cm)'].groupby(irisDF['flower name']).mean()[1], 
                irisDF['petal width (cm)'].groupby(irisDF['flower name']).mean()[1]]
virginica_means = [irisDF['sepal length (cm)'].groupby(irisDF['flower name']).mean()[2], 
                irisDF['sepal width (cm)'].groupby(irisDF['flower name']).mean()[2], 
                irisDF['petal length (cm)'].groupby(irisDF['flower name']).mean()[2], 
                irisDF['petal width (cm)'].groupby(irisDF['flower name']).mean()[2]]

# %%
# absdata['Genre'].groupby(absdata['Year']).size()

# %%
x = np.arange(len(labels))
width = 0.25

plt.bar(x - width, setosa_means, width, label='setosa')
plt.bar(x, versicolor_means, width, label='versicolor')
plt.bar(x + width, virginica_means, width, label='virginica')

plt.ylabel('Measurement (cm)')
plt.xticks(x, (labels))
plt.rcParams['axes.titlesize'] = 20
plt.title('Measurements by Species')
plt.legend()

plt.show()

# %% [markdown]
# ### Pie chart

# %%
size = 0.3

cmap = plt.get_cmap('tab20c')
colors = cmap(np.arange(4)*4)

plt.pie(setosa_means, radius=1, colors=colors, wedgeprops=dict(width=size, edgecolor='w'))
plt.pie(versicolor_means, radius=1-size, colors=colors, wedgeprops=dict(width=size, edgecolor='w'))
plt.pie(virginica_means, radius=1+size, colors=colors, wedgeprops=dict(width=size, edgecolor='w'))

# plt.legend()

plt.show()

# %%
size = 0.3
# fig, ax = plt.subplots(figsize = (8,8), constrained_layout=True)
fig, ax = plt.subplots()
fig.set_facecolor('white')


cmap = plt.get_cmap('tab20c')
colors = cmap(np.arange(4)*4)

plt.pie(setosa_means, radius=1+size, colors=cmap([0, 1, 2, 3]), labels=labels, 
        wedgeprops=dict(width=size, edgecolor='w'))
plt.pie(versicolor_means, radius=1, colors=cmap([4, 5, 6, 7]), 
        wedgeprops=dict(width=size, edgecolor='w'))
plt.pie(virginica_means, radius=1-size, colors=cmap([8, 9, 10, 11]),
        wedgeprops=dict(width=size, edgecolor='w'))

legend_elements = [Patch(facecolor=cmap([0])[0], label='setosa'), 
                   Patch(facecolor=cmap([4])[0], label='versicolor'), 
                   Patch(facecolor=cmap([8])[0], label='virginica')]
plt.legend(handles=legend_elements, loc=10)

plt.rcParams['axes.titley'] = 1.1
plt.rcParams['axes.titlesize'] = 20
plt.title('Relative Measurements by Species', loc='left')

plt.show()

# %%
from matplotlib.patches import Patch

# %%
legend_elements = [Patch(facecolor=cmap([0])[0], label='setosa'), 
                   Patch(facecolor=cmap([4])[0], label='versicolor'), 
                   Patch(facecolor=cmap([8])[0], label='virginica')]

# %%
cmap([0])[0]
# Out:
# array([0.19215686, 0.50980392, 0.74117647, 1.        ])

# %%
plt.Figure(facecolor='white')
